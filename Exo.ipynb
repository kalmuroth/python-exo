# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import gc

# %%
read = pd.read_csv(".input/sales_predictions.csv").sample(n=50, random_state=1)
#read = pd.to_datetime(read["date"], format='%d%m%Y')
test = sns.relplot(data=read, x="date", y="item_price")
print(test)

# %%
dataset = pd.read_csv("./input/IBM_HR_ATTRITION.csv").sample(n=50, random_state=1)
test = sns.catplot(data=dataset, x="Attrition", y="JobSatisfaction")
print(test)

# %%
dataset = pd.read_csv("./input/IBM_HR_ATTRITION.csv").sample(n=50, random_state=1)
test = sns.boxplot(data=dataset, x="Attrition", y="JobSatisfaction")
dataset.head()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1291   37       Yes      Travel_Rarely        370  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 720    30       Yes      Travel_Rarely        138  Research & Development
# 763    34        No      Travel_Rarely       1333                   Sales
# 976    56        No      Travel_Rarely       1369  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1291                10          4        Medical              1
# 1153                 3          2        Medical              1
# 720                 22          3  Life Sciences              1
# 763                 10          4  Life Sciences              1
# 976                 23          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
dataset = pd.read_csv("./input/IBM_HR_ATTRITION.csv").sample(n=50, random_state=1)
test = dataset.describe()
print(test)
# Out:
#             Age    DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  50.00000    50.000000         50.000000  50.000000           50.0
# mean   35.98000   779.940000          8.740000   2.760000            1.0
# std     9.74049   387.694989          7.173676   1.001224            0.0
# min    18.00000   117.000000          1.000000   1.000000            1.0
# 25%    29.00000   449.250000          3.000000   2.000000            1.0
# 50%    34.00000   797.000000          6.000000   3.000000            1.0
# 75%    41.00000  1095.750000         11.000000   3.750000            1.0
# max    56.00000  1372.000000         29.000000   4.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       50.000000                50.000000   50.000000       50.000000
# mean      1062.900000                 2.640000   70.400000        2.860000
# std        573.597073                 1.120496   21.233397        0.670364
# ...
