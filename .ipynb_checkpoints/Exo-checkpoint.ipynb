# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import gc

# %%
read = pd.read_csv(".input/sales_predictions.csv").sample(n=50, random_state=1)
#read = pd.to_datetime(read["date"], format='%d%m%Y')
test = sns.relplot(data=read, x="date", y="item_price")
print(test)

# %%
dataset = pd.read_csv("./input/IBM_HR_ATTRITION.csv").sample(n=50, random_state=1)
test = sns.relplot(data=dataset, x="date", y="item_price")
print(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 2
#       1 dataset = pd.read_csv("./input/IBM_HR_ATTRITION.csv").sample(n=50, random_state=1)
# ----> 2 test = sns.relplot(data=dataset, x="date", y="item_price")
#       3 print(test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:856, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     853     kwargs.pop("ax")
#     855 # Use the full dataset to map the semantics
# --> 856 p = plotter(
#     857     data=data,
#     858     variables=plotter.get_semantics(locals()),
#     859     legend=legend,
#     860 )
#     861 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
